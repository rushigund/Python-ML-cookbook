# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import PolynomialFeatures

dataset = np.array([[1,2],
                    [3,4]])

polynomial_features = PolynomialFeatures(degree=2,include_bias=False)
polynomial_features.fit_transform(dataset)
# Out:
# array([[ 1.,  2.,  1.,  2.,  4.],
#        [ 3.,  4.,  9., 12., 16.]])
