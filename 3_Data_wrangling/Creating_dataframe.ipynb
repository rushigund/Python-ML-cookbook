# %%
import pandas as pd
dataframe = pd.DataFrame()
dataframe["Student names"] = ["Alice", "Bob", "Charlie", "David"]
dataframe["Scores"] = [85, 92, 78, 90]
print(dataframe[::])
# Out:
#   Student names  Scores
# 0         Alice      85
# 1           Bob      92
# 2       Charlie      78
# 3         David      90
