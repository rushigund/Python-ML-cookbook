# %%
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv('titanic.csv')  # Example of loading a DataFrame

# %% [markdown]
# <h5>Applying conditions to filter out data</h5>

# %%
dataframe[(dataframe["Sex"]=="male") & (dataframe["Age"]>2)&(dataframe["Age"]<35)].head(5)
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
# 21           22         1       2           Beesley, Mr. Lawrence  male  34.0
# 23           24         1       1    Sloper, Mr. William Thompson  male  28.0
# 27           28         0       1  Fortune, Mr. Charles Alexander  male  19.0
#
#     SibSp  Parch     Ticket    Fare        Cabin Embarked
# 0       1      0  A/5 21171    7.25          NaN        S
# 12      0      0  A/5. 2151    8.05          NaN        S
# 21      0      0     248698   13.00          D56        S
# 23      0      0     113788   35.50           A6        S
# 27      3      2      19950  263.00  C23 C25 C27        S

# %% [markdown]
# <h5>Replacing column values by specified value</h5>

# %%
dataframe["Sex"].replace("female","Woman",inplace=True)
# Out:
# C:\Users\Rushikesh\AppData\Local\Temp\ipykernel_16336\1107113690.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe["Sex"].replace("female","Woman",inplace=True)

# %%
dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name    Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Woman  38.0      1
# 2                               Heikkinen, Miss. Laina  Woman  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Woman  35.0      1
# 4                             Allen, Mr. William Henry   male  35.0      0
# ..                                                 ...    ...   ...    ...
# ...

# %%
dataframe['Sex'].replace('male','Man',inplace=True)
# Out:
# C:\Users\Rushikesh\AppData\Local\Temp\ipykernel_16336\1792868035.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe['Sex'].replace('male','Man',inplace=True)

# %%
dataframe.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name    Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    Man  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  Woman  38.0      1
# 2                             Heikkinen, Miss. Laina  Woman  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Woman  35.0      1
# 4                           Allen, Mr. William Henry    Man  35.0      0
# 5                                   Moran, Mr. James    Man   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
dataframe["Cabin"].head(10)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %%
cabin_empty = dataframe["Cabin"].fillna(method = "ffill")
# Out:
# C:\Users\Rushikesh\AppData\Local\Temp\ipykernel_16336\967389843.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   cabin_empty = dataframe["Cabin"].fillna(method = "ffill")

# %%
cabin_empty.head(6)
# Out:
# 0     NaN
# 1     C85
# 2     C85
# 3    C123
# 4    C123
# 5    C123
# Name: Cabin, dtype: object

# %%
passengerClass = dataframe.rename(columns={"Pclass":"PassengerClass"})
passengerClass
# Out:
#      PassengerId  Survived  PassengerClass  \
# 0              1         0               3
# 1              2         1               1
# 2              3         1               3
# 3              4         1               1
# 4              5         0               3
# ..           ...       ...             ...
# 886          887         0               2
# 887          888         1               1
# 888          889         0               3
# 889          890         1               1
# 890          891         0               3
#
#                                                   Name    Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Man  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Woman  38.0      1
# 2                               Heikkinen, Miss. Laina  Woman  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Woman  35.0      1
# ...

# %%
from collections import defaultdict
new_names = defaultdict(str)

for name in dataframe.columns:
    new_names[name]

# %%
dataframe.rename(columns = {'PassengerId': '',
             'Survived': '',
             'Pclass': '',
             'Name': '',
             'Sex': '',
             'Age': '',
             'SibSp': '',
             'Parch': '',
             'Ticket': '',
             'Fare': '',
             'Cabin': '',
             'Embarked': ''})
# Out:
#                                                                           \
# 0      1  0  3                            Braund, Mr. Owen Harris    Man
# 1      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  Woman
# 2      3  1  3                             Heikkinen, Miss. Laina  Woman
# 3      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Woman
# 4      5  0  3                           Allen, Mr. William Henry    Man
# ..   ... .. ..                                                ...    ...
# 886  887  0  2                              Montvila, Rev. Juozas    Man
# 887  888  1  1                       Graham, Miss. Margaret Edith  Woman
# 888  889  0  3           Johnston, Miss. Catherine Helen "Carrie"  Woman
# 889  890  1  1                              Behr, Mr. Karl Howell    Man
# 890  891  0  3                                Dooley, Mr. Patrick    Man
#
#
# 0    22.0  1  0         A/5 21171   7.2500   NaN  S
# ...

# %%
print(dataframe["Age"].max())
print(dataframe["Age"].min())
print(dataframe["Age"].count())
print(dataframe["Age"].mean())
print("Age sum",dataframe["Age"].sum())
# Out:
# 80.0
# 0.42
# 714
# 29.69911764705882
# Age sum 21205.17

# %%
print(dataframe["Age"].unique())
print(dataframe["Age"].nunique())
print(dataframe["Age"].value_counts())
# Out:
# [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]
# 88
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
dataframe["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
dataframe["Age"].replace('23',np.nan)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
