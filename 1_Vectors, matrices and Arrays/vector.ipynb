# %%
import numpy as np

# %%
array_row = np.array([1,2,3])

# %%
array_col= np.array([[1],
                    [2],
                    [3]])

# %%
print("Row vector shape:", array_row.shape)
print("Column vector shape:", array_col.shape)
# Out:
# Row vector shape: (3,)
# Column vector shape: (3, 1)
